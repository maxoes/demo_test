# %% [markdown]
# # :My Jupyter Notebook on IBM Watson Studio:

# %% [markdown]
# __Maximilian Oesing__
# Senior Analyst

# %% [markdown]
# *I am interested in data science, because I want to build tools to improve my companies understanding of our data. Further, I want to optimize the very old-fashioned business style based on experience and anecdotes of my colleagues.

# %% [markdown]
# ### Below I divide by zero, dont tell anyone!

# %%
100 % 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/wsuser/ipykernel_164/2682460950.py in <module>
# ----> 1 100 % 0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# So this is a link to a youtube video below:
#
#
# ******
#
#
# [its an inline link to IBM](https://ibm.com)
#
#
# _______
#
#
#
# ```python
# test = "how to highlight syntax"
# print test
# ```
